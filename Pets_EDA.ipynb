# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikant78/DSSummit/blob/master/Pets_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp

# %%
! pip install pandas==0.25
# Out:
# ...
#      |████████████████████████████████| 10.5MB 2.7MB/s
# ...
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.25.0 which is incompatible.
# ...
#   Found existing installation: pandas 1.0.5
#     Uninstalling pandas-1.0.5:
#       Successfully uninstalled pandas-1.0.5
# ...

# %%
train = pd.read_csv("/content/train.csv")
train.head()
# Out:
#        pet_id           issue_date  ... breed_category  pet_category
# 0  ANSL_69903  2016-07-10 00:00:00  ...            0.0             1
# 1  ANSL_66892  2013-11-21 00:00:00  ...            0.0             2
# 2  ANSL_69750  2014-09-28 00:00:00  ...            2.0             4
# 3  ANSL_71623  2016-12-31 00:00:00  ...            0.0             2
# 4  ANSL_57969  2017-09-28 00:00:00  ...            0.0             1
#
# [5 rows x 11 columns]

# %%
pp.ProfileReport(train)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_profiling/describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
train.head()
# Out:
#        pet_id           issue_date  ... breed_category  pet_category
# 0  ANSL_69903  2016-07-10 00:00:00  ...            0.0             1
# 1  ANSL_66892  2013-11-21 00:00:00  ...            0.0             2
# 2  ANSL_69750  2014-09-28 00:00:00  ...            2.0             4
# 3  ANSL_71623  2016-12-31 00:00:00  ...            0.0             2
# 4  ANSL_57969  2017-09-28 00:00:00  ...            0.0             1
#
# [5 rows x 11 columns]

# %%
train['breed_category'].unique()
# Out:
# array([0., 2., 1.])

# %%
train['pet_category'].unique()
#2 dog
#1
# Out:
# array([1, 2, 4, 0])

# %%
train['color_type'].unique()
# Out:
# array(['Brown Tabby', 'White', 'Brown', 'Black', 'Red', 'Tricolor',
#        'Calico', 'Brown Brindle', 'Blue', 'Tortie', 'Gray', 'Fawn',
#        'Buff', 'Torbie', 'Orange Tabby', 'Sable', 'Tan', 'Blue Tick',
#        'Orange', 'Blue Tabby', 'Chocolate', 'Black Tabby',
#        'Black Brindle', 'Cream Tabby', 'Gold', 'Calico Point',
#        'Blue Merle', 'Red Merle', 'Yellow', 'Lynx Point', 'Blue Cream',
#        'Flame Point', 'Cream', 'Yellow Brindle', 'Blue Tiger',
#        'Seal Point', 'Red Tick', 'Brown Merle', 'Black Smoke',
#        'Gray Tabby', 'Green', 'Tortie Point', 'Blue Smoke', 'Apricot',
#        'Blue Point', 'Silver Tabby', 'Lilac Point', 'Silver',
#        'Brown Tiger', 'Liver', 'Agouti', 'Chocolate Point', 'Liver Tick',
#        'Pink', 'Black Tiger', 'Silver Lynx Point'], dtype=object)

# %%
target_count = train.color_type.value_counts()
target_count.head(150)
# Out:
# Black                4620
# White                2453
# Brown                1791
# Brown Tabby          1687
# Tan                  1349
# Blue                  852
# Orange Tabby          791
# Red                   526
# Brown Brindle         496
# Tricolor              469
# Blue Tabby            386
# Tortie                366
# Calico                343
# Gray                  307
# Chocolate             259
# Torbie                242
# Cream Tabby           191
# Sable                 167
# Cream                 162
# Fawn                  159
# Yellow                143
# Buff                  125
# Lynx Point            117
# Blue Merle            104
# Seal Point             78
# Black Brindle          66
# Gray Tabby             65
# Black Tabby            55
# Flame Point            52
# Brown Merle            39
# Orange                 39
# Black Smoke            32
# Gold                   31
# Tortie Point           26
# Silver                 24
# ...

# %%
df1 = train['color_type']=='Blue Cream'
df2 = train[df1]
df2.head(10)
# Out:
#            pet_id           issue_date  ... breed_category  pet_category
# 397    ANSL_67290  2017-08-04 00:00:00  ...            1.0             1
# 1598   ANSL_76079  2017-07-04 00:00:00  ...            1.0             1
# 3513   ANSL_63661  2014-06-29 00:00:00  ...            1.0             2
# 3754   ANSL_61644  2014-06-15 00:00:00  ...            1.0             1
# 4325   ANSL_66879  2018-10-31 00:00:00  ...            1.0             1
# 7594   ANSL_69606  2016-12-23 00:00:00  ...            0.0             2
# 8515   ANSL_67725  2018-10-24 00:00:00  ...            1.0             1
# 9547   ANSL_68469  2003-06-29 00:00:00  ...            1.0             1
# 17392  ANSL_76465  2019-01-10 00:00:00  ...            1.0             1
# 17422  ANSL_64796  2015-12-24 00:00:00  ...            1.0             2
#
# [10 rows x 11 columns]

# %%
# Out:
#          pet_id           issue_date  ... breed_category  pet_category
# 18   ANSL_55607  2013-11-28 00:00:00  ...            1.0             2
# 126  ANSL_66720  2017-10-26 00:00:00  ...            0.0             2
# 139  ANSL_71574  2016-04-09 00:00:00  ...            1.0             2
# 201  ANSL_71410  2015-08-05 00:00:00  ...            1.0             2
# 214  ANSL_65469  2017-08-31 00:00:00  ...            1.0             2
#
# [5 rows x 11 columns]

# %%
target_count = train.breed_category.value_counts()
target_count.head()
# Out:
# 0.0    9000
# 1.0    8357
# 2.0    1477
# Name: breed_category, dtype: int64

# %%
target_count = train.pet_category.value_counts()
target_count.head()
# Out:
# 2    10621
# 1     7184
# 4      941
# 0       88
# Name: pet_category, dtype: int64

# %%
train[['pet_category','X1', 'pet_id']].groupby(['pet_category','X1']).count()
# Out:
#                  pet_id
# pet_category X1
# 0            0       46
#              7        7
#              11       4
#              12       2
#              13      13
#              18      16
# 1            0     2869
#              1        1
#              2       13
#              6        3
#              7      921
#              8       40
#              9       64
#              10       3
#              11      11
#              12      13
#              13    2062
#              15      11
#              16     603
#              17     260
#              18     309
#              19       1
# 2            0     7683
#              1       50
#              2       10
#              3        1
#              4        7
#              5        3
#              6        2
#              7      528
#              8        5
#              9       28
#              10       2
#              11      10
#              12      49
#              13    2099
# ...

# %%
train[['pet_category','X2', 'pet_id']].groupby(['pet_category','X2']).count()
# Out:
#                  pet_id
# pet_category X2
# 0            1       37
#              2        1
#              3        8
#              4       21
#              6        3
#              7        5
#              9       13
# 1            0        1
#              1     3416
#              2      111
#              3        9
#              4      346
#              5        9
#              7      353
#              8       14
#              9     2925
# 2            0        3
#              1     4967
#              2       44
#              3        3
#              4      219
#              5        3
#              7     3238
#              8       44
#              9     2100
# 4            1       73
#              2       27
#              3       44
#              4      677
#              6        2
#              7       12
#              9      106

# %%
train.corr()
# Out:
#                 condition  length(m)  ...  breed_category  pet_category
# condition        1.000000  -0.011219  ...       -0.483503     -0.041660
# length(m)       -0.011219   1.000000  ...        0.007229     -0.003999
# height(cm)      -0.010793  -0.004464  ...        0.011647      0.001976
# X1               0.338843  -0.002893  ...        0.240729     -0.032594
# X2               0.381696  -0.011175  ...        0.052530     -0.032116
# breed_category  -0.483503   0.007229  ...        1.000000      0.209230
# pet_category    -0.041660  -0.003999  ...        0.209230      1.000000
#
# [7 rows x 7 columns]

# %%
train.describe()
# Out:
#           condition     length(m)  ...  breed_category  pet_category
# count  17357.000000  18834.000000  ...    18834.000000  18834.000000
# mean       0.883390      0.502636  ...        0.600563      1.709143
# std        0.770434      0.288705  ...        0.629883      0.717919
# min        0.000000      0.000000  ...        0.000000      0.000000
# 25%        0.000000      0.250000  ...        0.000000      1.000000
# 50%        1.000000      0.500000  ...        1.000000      2.000000
# 75%        1.000000      0.760000  ...        1.000000      2.000000
# max        2.000000      1.000000  ...        2.000000      4.000000
#
# [8 rows x 7 columns]

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
train = train.fillna(-99)
sns.countplot(train['condition'], hue=train['breed_category'])
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.countplot(train['breed_category'], hue=train['pet_category'])
